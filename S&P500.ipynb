# %% [markdown]
# <a href="https://colab.research.google.com/github/falloatti/SYP500/blob/main/S%26P500.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **PROYECTO 2, S&P 500**

# %% [markdown]
# ![bb2.jpeg](data:image/jpeg;base64,...)

# %%
# !pip install yfinance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.3/59.3 KB 1.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.3/114.3 KB 4.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 21.0 MB/s eta 0:00:00
# ...

# %% [markdown]
# **IMPORTAR INFO DE YAHOO FINANCE**

# %%
import yfinance as yf
import pandas as pd

# Obtener todos los símbolos de acciones del S&P 500
sp500 = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')[0]
sp500_symbols = sp500['Symbol'].tolist()

# Definir el rango de fechas
start_date = '2000-01-01'
end_date = '2023-03-22'

# Crear un DataFrame vacío para almacenar los datos
sp500_data = pd.DataFrame()

# Iterar a través de cada símbolo de acción y agregar los datos
for symbol in sp500_symbols:
    print(f"Descargando datos para {symbol}...")
    data = yf.download(symbol, start=start_date, end=end_date)
    if len(data) > 0:
        data['Symbol'] = symbol
        sp500_data = sp500_data.append(data)
# Out:
# Descargando datos para MMM...
# [*********************100%***********************]  1 of 1 completed
# Descargando datos para AOS...
# <ipython-input-2-263f881ec587>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sp500_data = sp500_data.append(data)
# [*********************100%***********************]  1 of 1 completed
# Descargando datos para ABT...
# <ipython-input-2-263f881ec587>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sp500_data = sp500_data.append(data)
# [*********************100%***********************]  1 of 1 completed
# Descargando datos para ABBV...
# <ipython-input-2-263f881ec587>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sp500_data = sp500_data.append(data)
# ...

# %%
sp500_data = sp500_data.reset_index()

# %%
sp500_data.head()
# Out:
#         Date      Open      High       Low    Close  Adj Close   Volume Symbol
# 0 2000-01-03  48.03125  48.25000  47.03125  47.1875  25.525517  2173400    MMM
# 1 2000-01-04  46.43750  47.40625  45.31250  45.3125  24.511263  2713800    MMM
# 2 2000-01-05  45.56250  48.12500  45.56250  46.6250  25.221237  3699400    MMM
# 3 2000-01-06  47.15625  51.25000  47.15625  50.3750  27.249758  5975800    MMM
# 4 2000-01-07  50.56250  51.90625  49.96875  51.3750  27.790689  4101200    MMM

# %% [markdown]
# **Ver tamano dataset**

# %%
sp500_data.shape
# Out:
# (2613850, 8)

# %%
lista = sp500_data['Symbol'].unique().tolist()

# %%
print(lista)
# Out:
# ['MMM', 'AOS', 'ABT', 'ABBV', 'ACN', 'ATVI', 'ADM', 'ADBE', 'ADP', 'AAP', 'AES', 'AFL', 'A', 'APD', 'AKAM', 'ALK', 'ALB', 'ARE', 'ALGN', 'ALLE', 'LNT', 'ALL', 'GOOGL', 'GOOG', 'MO', 'AMZN', 'AMCR', 'AMD', 'AEE', 'AAL', 'AEP', 'AXP', 'AIG', 'AMT', 'AWK', 'AMP', 'ABC', 'AME', 'AMGN', 'APH', 'ADI', 'ANSS', 'AON', 'APA', 'AAPL', 'AMAT', 'APTV', 'ACGL', 'ANET', 'AJG', 'AIZ', 'T', 'ATO', 'ADSK', 'AZO', 'AVB', 'AVY', 'BKR', 'BALL', 'BAC', 'BBWI', 'BAX', 'BDX', 'WRB', 'BBY', 'BIO', 'TECH', 'BIIB', 'BLK', 'BK', 'BA', 'BKNG', 'BWA', 'BXP', 'BSX', 'BMY', 'AVGO', 'BR', 'BRO', 'BG', 'CHRW', 'CDNS', 'CZR', 'CPT', 'CPB', 'COF', 'CAH', 'KMX', 'CCL', 'CARR', 'CTLT', 'CAT', 'CBOE', 'CBRE', 'CDW', 'CE', 'CNC', 'CNP', 'CDAY', 'CF', 'CRL', 'SCHW', 'CHTR', 'CVX', 'CMG', 'CB', 'CHD', 'CI', 'CINF', 'CTAS', 'CSCO', 'C', 'CFG', 'CLX', 'CME', 'CMS', 'KO', 'CTSH', 'CL', 'CMCSA', 'CMA', 'CAG', 'COP', 'ED', 'STZ', 'CEG', 'COO', 'CPRT', 'GLW', 'CTVA', 'CSGP', 'COST', 'CTRA', 'CCI', 'CSX', 'CMI', 'CVS', 'DHI', 'DHR
# ...

# %%
print(sp500_data.Symbol.unique)
# Out:
# <bound method Series.unique of 0          MMM
# 1          MMM
# 2          MMM
# 3          MMM
# 4          MMM
#           ...
# 2613845    ZTS
# 2613846    ZTS
# 2613847    ZTS
# 2613848    ZTS
# 2613849    ZTS
# Name: Symbol, Length: 2613850, dtype: object>

# %%
# Definir la lista de símbolos de Yahoo Finance
symbols = ['MMM', 'AOS', 'ABT', 'ABBV', 'ACN', 'ATVI', 'ADM', 'ADBE', 'ADP', 'AAP', 'AES', 'AFL', 'A', 'APD', 'AKAM', 'ALK', 'ALB', 'ARE', 'ALGN', 'ALLE', 'LNT', 'ALL', 'GOOGL', 'GOOG', 'MO', 'AMZN', 'AMCR', 'AMD', 'AEE', 'AAL', 'AEP', 'AXP', 'AIG', 'AMT', 'AWK', 'AMP', 'ABC', 'AME', 'AMGN', 'APH', 'ADI', 'ANSS', 'AON', 'APA', 'AAPL', 'AMAT', 'APTV', 'ACGL', 'ANET', 'AJG', 'AIZ', 'T', 'ATO', 'ADSK', 'AZO', 'AVB', 'AVY', 'BKR', 'BALL', 'BAC', 'BBWI', 'BAX', 'BDX', 'WRB', 'BBY', 'BIO', 'TECH', 'BIIB', 'BLK', 'BK', 'BA', 'BKNG', 'BWA', 'BXP', 'BSX', 'BMY', 'AVGO', 'BR', 'BRO', 'CHRW', 'CDNS', 'CZR', 'CPT', 'CPB', 'COF', 'CAH', 'KMX', 'CCL', 'CARR', 'CTLT', 'CAT', 'CBOE', 'CBRE', 'CDW', 'CE', 'CNC', 'CNP', 'CDAY', 'CF', 'CRL', 'SCHW', 'CHTR', 'CVX', 'CMG', 'CB', 'CHD', 'CI', 'CINF', 'CTAS', 'CSCO', 'C', 'CFG', 'CLX', 'CME', 'CMS', 'KO', 'CTSH', 'CL', 'CMCSA', 'CMA', 'CAG', 'COP', 'ED', 'STZ', 'CEG', 'COO', 'CPRT', 'GLW', 'CTVA', 'CSGP', 'COST', 'CTRA', 'CCI', 'CSX', 'CMI', 'CVS', 'DHI', 'DHR', 'DRI', 'DVA', 'DE', 'DAL', 'XRAY', 'DVN', 'DXCM', 'FANG', 'DLR', 'DFS', 'DISH', 'DIS', 'DG', 'DLTR', 'D', 'DPZ', 'DOV', 'DOW', 'DTE', 'DUK', 'DD', 'DXC', 'EMN', 'ETN', 'EBAY', 'ECL', 'EIX', 'EW', 'EA', 'ELV', 'LLY', 'EMR', 'ENPH', 'ETR', 'EOG', 'EPAM', 'EQT', 'EFX', 'EQIX', 'EQR', 'ESS', 'EL', 'ETSY', 'RE', 'EVRG', 'ES', 'EXC', 'EXPE', 'EXPD', 'EXR', 'XOM', 'FFIV', 'FDS', 'FAST', 'FRT', 'FDX', 'FITB', 'FRC', 'FSLR', 'FE', 'FIS', 'FISV', 'FLT', 'FMC', 'F', 'FTNT', 'FTV', 'FOXA', 'FOX', 'BEN', 'FCX', 'GRMN', 'IT', 'GEHC', 'GEN', 'GNRC', 'GD', 'GE', 'GIS', 'GM', 'GPC', 'GILD', 'GL', 'GPN', 'GS', 'HAL', 'HIG', 'HAS', 'HCA', 'PEAK', 'HSIC', 'HSY', 'HES', 'HPE', 'HLT', 'HOLX', 'HD', 'HON', 'HRL', 'HST', 'HWM', 'HPQ', 'HUM', 'HBAN', 'HII', 'IBM', 'IEX', 'IDXX', 'ITW', 'ILMN', 'INCY', 'IR', 'INTC', 'ICE', 'IFF', 'IP', 'IPG', 'INTU', 'ISRG', 'IVZ', 'INVH', 'IQV', 'IRM', 'JBHT', 'JKHY', 'J', 'JNJ', 'JCI', 'JPM', 'JNPR', 'K', 'KDP', 'KEY', 'KEYS', 'KMB', 'KIM', 'KMI', 'KLAC', 'KHC', 'KR', 'LHX', 'LH', 'LRCX', 'LW', 'LVS', 'LDOS', 'LEN', 'LNC', 'LIN', 'LYV', 'LKQ', 'LMT', 'L', 'LOW', 'LUMN', 'LYB', 'MTB', 'MRO', 'MPC', 'MKTX', 'MAR', 'MMC', 'MLM', 'MAS', 'MA', 'MTCH', 'MKC', 'MCD', 'MCK', 'MDT', 'MRK', 'META', 'MET', 'MTD', 'MGM', 'MCHP', 'MU', 'MSFT', 'MAA', 'MRNA', 'MHK', 'MOH', 'TAP', 'MDLZ', 'MPWR', 'MNST', 'MCO', 'MS', 'MOS', 'MSI', 'MSCI', 'NDAQ', 'NTAP', 'NFLX', 'NWL', 'NEM', 'NWSA', 'NWS', 'NEE', 'NKE', 'NI', 'NDSN', 'NSC', 'NTRS', 'NOC', 'NCLH', 'NRG', 'NUE', 'NVDA', 'NVR', 'NXPI', 'ORLY', 'OXY', 'ODFL', 'OMC', 'ON', 'OKE', 'ORCL', 'OGN', 'OTIS', 'PCAR', 'PKG', 'PARA', 'PH', 'PAYX', 'PAYC', 'PYPL', 'PNR', 'PEP', 'PKI', 'PFE', 'PCG', 'PM', 'PSX', 'PNW', 'PXD', 'PNC', 'POOL', 'PPG', 'PPL', 'PFG', 'PG', 'PGR', 'PLD', 'PRU', 'PEG', 'PTC', 'PSA', 'PHM', 'QRVO', 'PWR', 'QCOM', 'DGX', 'RL', 'RJF', 'RTX', 'O', 'REG', 'REGN', 'RF', 'RSG', 'RMD', 'RHI', 'ROK', 'ROL', 'ROP', 'ROST', 'RCL', 'SPGI', 'CRM', 'SBAC', 'SLB', 'STX', 'SEE', 'SRE', 'NOW', 'SHW', 'SBNY', 'SPG', 'SWKS', 'SJM', 'SNA', 'SEDG', 'SO', 'LUV', 'SWK', 'SBUX', 'STT', 'STLD', 'STE', 'SYK', 'SIVB', 'SYF', 'SNPS', 'SYY', 'TMUS', 'TROW', 'TTWO', 'TPR', 'TRGP', 'TGT', 'TEL', 'TDY', 'TFX', 'TER', 'TSLA', 'TXN', 'TXT', 'TMO', 'TJX', 'TSCO', 'TT', 'TDG', 'TRV', 'TRMB', 'TFC', 'TYL', 'TSN', 'USB', 'UDR', 'ULTA', 'UNP', 'UAL', 'UPS', 'URI', 'UNH', 'UHS', 'VLO', 'VTR', 'VRSN', 'VRSK', 'VZ', 'VRTX', 'VFC', 'VTRS', 'VICI', 'V', 'VMC', 'WAB', 'WBA', 'WMT', 'WBD', 'WM', 'WAT', 'WEC', 'WFC', 'WELL', 'WST', 'WDC', 'WRK', 'WY', 'WHR', 'WMB', 'WTW', 'GWW', 'WYNN', 'XEL', 'XYL', 'YUM', 'ZBRA', 'ZBH', 'ZION', 'ZTS']

# %% [markdown]
# **Ver cuantas empreas son**

# %%
print(len(symbols))
# Out:
# 501

# %% [markdown]
# **BUSCAR INFO ADICIONAL**

# %%
url = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"

# %%
# Usar la función read_html() para leer la tabla desde la página web
tables = pd.read_html(url)

# %%
# La tabla que nos interesa es la primera
sp500_table = tables[0]

# %%
# Imprimir los primeros cinco registros del DataFrame
sp500_table.head()
# Out:
#   Symbol     Security             GICS Sector               GICS Sub-Industry  \
# 0    MMM           3M             Industrials        Industrial Conglomerates
# 1    AOS  A. O. Smith             Industrials               Building Products
# 2    ABT       Abbott             Health Care           Health Care Equipment
# 3   ABBV       AbbVie             Health Care                 Pharmaceuticals
# 4    ACN    Accenture  Information Technology  IT Consulting & Other Services
#
#      Headquarters Location  Date added      CIK      Founded
# 0    Saint Paul, Minnesota  1957-03-04    66740         1902
# 1     Milwaukee, Wisconsin  2017-07-26    91142         1916
# 2  North Chicago, Illinois  1957-03-04     1800         1888
# 3  North Chicago, Illinois  2012-12-31  1551152  2013 (1888)
# 4          Dublin, Ireland  2011-07-06  1467373         1989

# %%
lista2 = sp500_data['Symbol'].unique().tolist()

# %% [markdown]
# **Chequear que sea la misma cantidad**

# %%
print(len(lista2))
# Out:
# 501

# %%
sp500_data.head()
# Out:
#         Date      Open      High       Low    Close  Adj Close   Volume Symbol
# 0 2000-01-03  48.03125  48.25000  47.03125  47.1875  25.525517  2173400    MMM
# 1 2000-01-04  46.43750  47.40625  45.31250  45.3125  24.511263  2713800    MMM
# 2 2000-01-05  45.56250  48.12500  45.56250  46.6250  25.221237  3699400    MMM
# 3 2000-01-06  47.15625  51.25000  47.15625  50.3750  27.249758  5975800    MMM
# 4 2000-01-07  50.56250  51.90625  49.96875  51.3750  27.790689  4101200    MMM

# %% [markdown]
# **AGREGAR INFO ADICIONAL AL DATASET**

# %%
# Fusionar los dataframes en función de la columna CustomerID
merged_df = pd.merge(sp500_data, sp500_table, on='Symbol')

# %%
merged_df.head()
# Out:
#         Date      Open      High       Low    Close  Adj Close   Volume  \
# 0 2000-01-03  48.03125  48.25000  47.03125  47.1875  25.525517  2173400
# 1 2000-01-04  46.43750  47.40625  45.31250  45.3125  24.511263  2713800
# 2 2000-01-05  45.56250  48.12500  45.56250  46.6250  25.221237  3699400
# 3 2000-01-06  47.15625  51.25000  47.15625  50.3750  27.249758  5975800
# 4 2000-01-07  50.56250  51.90625  49.96875  51.3750  27.790689  4101200
#
#   Symbol Security  GICS Sector         GICS Sub-Industry  \
# 0    MMM       3M  Industrials  Industrial Conglomerates
# 1    MMM       3M  Industrials  Industrial Conglomerates
# 2    MMM       3M  Industrials  Industrial Conglomerates
# 3    MMM       3M  Industrials  Industrial Conglomerates
# 4    MMM       3M  Industrials  Industrial Conglomerates
#
#    Headquarters Location  Date added    CIK Founded
# 0  Saint Paul, Minnesota  1957-03-04  66740    1902
# 1  Saint Paul, Minnesota  1957-03-04  66740    1902
# ...

# %%
unique_date = merged_df['Date'].nunique()
print(unique_date)
# Out:
# 5841

# %% [markdown]
# **Ahora el dataset quedo de 2613850 filas y 15 columnas**

# %%
merged_df.shape
# Out:
# (2613850, 15)

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2613850 entries, 0 to 2613849
# Data columns (total 15 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Date                   datetime64[ns]
#  1   Open                   float64
#  2   High                   float64
#  3   Low                    float64
#  4   Close                  float64
#  5   Adj Close              float64
#  6   Volume                 int64
#  7   Symbol                 object
#  8   Security               object
#  9   GICS Sector            object
#  10  GICS Sub-Industry      object
#  11  Headquarters Location  object
#  12  Date added             object
#  13  CIK                    int64
#  14  Founded                object
# dtypes: datetime64[ns](1), float64(5), int64(2), object(7)
# memory usage: 319.1+ MB

# %%
# Agregar una columna con el día de la semana correspondiente
dias_de_la_semana = {
    0: 'Lunes',
    1: 'Martes',
    2: 'Miércoles',
    3: 'Jueves',
    4: 'Viernes',
    5: 'Sábado',
    6: 'Domingo'
}
merged_df['Dia'] = merged_df['Date'].dt.dayofweek.map(dias_de_la_semana)

# %%
merged_df.tail()
# Out:
#               Date        Open        High         Low       Close  \
# 2613845 2023-03-15  162.000000  163.679993  160.119995  163.570007
# 2613846 2023-03-16  162.509995  166.839996  162.250000  166.309998
# 2613847 2023-03-17  167.289993  168.389999  163.649994  164.470001
# 2613848 2023-03-20  164.000000  165.949997  163.699997  165.820007
# 2613849 2023-03-21  166.649994  166.990005  165.139999  166.240005
#
#           Adj Close   Volume Symbol Security  GICS Sector GICS Sub-Industry  \
# 2613845  163.570007  1824100    ZTS   Zoetis  Health Care   Pharmaceuticals
# 2613846  166.309998  2040500    ZTS   Zoetis  Health Care   Pharmaceuticals
# 2613847  164.470001  3605100    ZTS   Zoetis  Health Care   Pharmaceuticals
# 2613848  165.820007  2145800    ZTS   Zoetis  Health Care   Pharmaceuticals
# 2613849  166.240005  2453500    ZTS   Zoetis  Health Care   Pharmaceuticals
#
#           Headquarters Location  Date added      CIK Founded        Dia
# ...

# %%
# !pip install mplfinance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 KB 3.0 MB/s eta 0:00:00
# ...

# %%
merged_df['Symbol'] = merged_df['Symbol'].astype(str)

# %%
merged_df['Symbol'] = merged_df['Symbol'].str.strip()

# %%
merged_df.set_index('Date', inplace=True)

# %% [markdown]
# **GRAFICO DE VELAS**

# %%
import mplfinance as mpf

# Filtrar los datos de una acción específica y fechas específicas
symbol = 'AAPL'
start_date = '2000-01-01'
end_date = '2023-03-22'
filtered_df = merged_df.loc[(merged_df['Symbol'] == symbol) & (merged_df.index >= start_date) & (merged_df.index <= end_date)]

# Crear el gráfico de velas
mpf.plot(filtered_df, type='candle', volume=True, style='charles', title=f'Gráfico de velas para {symbol}', ylabel='Precio ($)')
# Out:
# /usr/local/lib/python3.9/dist-packages/mplfinance/_arg_validators.py:83: UserWarning:
#
# ...
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
# ...
#   warnings.warn('\n\n ================================================================= '+

# %%
# Crear una columna que calcule la diferencia entre el precio de apertura y cierre para cada día
merged_df['Dif Open-Close'] = merged_df['Close'] - merged_df['Open']

# %%
merged_df.head(1)
# Out:
#                 Open   High       Low    Close  Adj Close   Volume Symbol  \
# Date
# 2000-01-03  48.03125  48.25  47.03125  47.1875  25.525517  2173400    MMM
#
#            Security  GICS Sector         GICS Sub-Industry  \
# Date
# 2000-01-03       3M  Industrials  Industrial Conglomerates
#
#             Headquarters Location  Date added    CIK Founded    Dia  \
# Date
# 2000-01-03  Saint Paul, Minnesota  1957-03-04  66740    1902  Lunes
#
#             Dif Open-Close
# Date
# 2000-01-03        -0.84375

# %% [markdown]
# **CUANDO COMPRAR**

# %%
merged_df['Dif_Sign'] = merged_df['Dif Open-Close'].apply(lambda x: 1 if x > 0 else (-1 if x < 0 else 0))

# %%
merged_df.head()
# Out:
#                 Open      High       Low    Close  Adj Close   Volume Symbol  \
# Date
# 2000-01-03  48.03125  48.25000  47.03125  47.1875  25.525517  2173400    MMM
# 2000-01-04  46.43750  47.40625  45.31250  45.3125  24.511263  2713800    MMM
# 2000-01-05  45.56250  48.12500  45.56250  46.6250  25.221237  3699400    MMM
# 2000-01-06  47.15625  51.25000  47.15625  50.3750  27.249758  5975800    MMM
# 2000-01-07  50.56250  51.90625  49.96875  51.3750  27.790689  4101200    MMM
#
#            Security  GICS Sector         GICS Sub-Industry  \
# Date
# 2000-01-03       3M  Industrials  Industrial Conglomerates
# 2000-01-04       3M  Industrials  Industrial Conglomerates
# 2000-01-05       3M  Industrials  Industrial Conglomerates
# 2000-01-06       3M  Industrials  Industrial Conglomerates
# 2000-01-07       3M  Industrials  Industrial Conglomerates
#
#             Headquarters Location  Date added    CIK Founded        Dia  \
# Date
# ...

# %%
import matplotlib.pyplot as plt

# %%
# Agrupar los datos por día y calcular la suma de los valores
suma_valores = merged_df.groupby('Dia')['Dif_Sign'].sum()

# Crear el gráfico de barras
suma_valores.plot(kind='bar')

# Configurar los ejes y etiquetas
plt.xlabel('Día de la semana')
plt.ylabel('Suma de valores')

# Mostrar el gráfico
plt.show()

# %%
merged_df = merged_df.reset_index()

# %%
# Definir los parámetros de filtrado
fecha_desde = '2018-01-01'
fecha_hasta = '2023-02-22'

# Filtrar los datos por símbolo y rango de fechas
datos_filtrados = merged_df.loc[(merged_df['Symbol'] == 'AAPL') &
                            (merged_df['Date'] >= fecha_desde) &
                            (merged_df['Date'] <= fecha_hasta)]

# Agrupar los datos por día y calcular la suma de los valores
suma_valores = datos_filtrados.groupby('Dia')['Dif_Sign'].sum()

# Crear el gráfico de barras
suma_valores.plot(kind='bar')

# Configurar los ejes y etiquetas
plt.xlabel('Día de la semana')
plt.ylabel('Suma de valores')
plt.title('Valores para la empresa {} desde {} hasta {}'.format('AAPL', fecha_desde, fecha_hasta))

# Mostrar el gráfico
plt.show()

# %%
# Escribir el DataFrame en un archivo Parquet
merged_df.to_parquet('datos.parquet', engine='pyarrow')

# %%
merged_df.head()
# Out:
#         Date      Open      High       Low    Close  Adj Close   Volume  \
# 0 2000-01-03  48.03125  48.25000  47.03125  47.1875  25.525517  2173400
# 1 2000-01-04  46.43750  47.40625  45.31250  45.3125  24.511263  2713800
# 2 2000-01-05  45.56250  48.12500  45.56250  46.6250  25.221237  3699400
# 3 2000-01-06  47.15625  51.25000  47.15625  50.3750  27.249758  5975800
# 4 2000-01-07  50.56250  51.90625  49.96875  51.3750  27.790689  4101200
#
#   Symbol Security  GICS Sector         GICS Sub-Industry  \
# 0    MMM       3M  Industrials  Industrial Conglomerates
# 1    MMM       3M  Industrials  Industrial Conglomerates
# 2    MMM       3M  Industrials  Industrial Conglomerates
# 3    MMM       3M  Industrials  Industrial Conglomerates
# 4    MMM       3M  Industrials  Industrial Conglomerates
#
#    Headquarters Location  Date added    CIK Founded        Dia  \
# 0  Saint Paul, Minnesota  1957-03-04  66740    1902      Lunes
# ...

# %%
merged_df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'Symbol',
#        'Security', 'GICS Sector', 'GICS Sub-Industry', 'Headquarters Location',
#        'Date added', 'CIK', 'Founded', 'Dia', 'Dif Open-Close', 'Dif_Sign'],
#       dtype='object')

# %%
# Ordenar el DataFrame por símbolo y fecha
merged_df = merged_df.sort_values(by=['Symbol', 'Date'])

# Calcular la SMA de 50 días para cada símbolo
merged_df['SMA_50'] = merged_df.groupby('Symbol')['Close'].rolling(window=50).mean().reset_index(drop=True)

# Calcular la SMA de 200 días para cada símbolo
merged_df['SMA_200'] = merged_df.groupby('Symbol')['Close'].rolling(window=200).mean().reset_index(drop=True)

# Calcular la EMA de 12 días para cada símbolo
merged_df['EMA_12'] = merged_df.groupby('Symbol')['Close'].apply(lambda x: x.ewm(span=12).mean()).reset_index(drop=True)

# Calcular la EMA de 26 días para cada símbolo
merged_df['EMA_26'] = merged_df.groupby('Symbol')['Close'].apply(lambda x: x.ewm(span=26).mean()).reset_index(drop=True)

# %%
merged_df.head()
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 65956 2000-01-03  56.330471  56.464592  48.193848  51.502148  44.001278
# 65957 2000-01-04  48.730328  49.266811  46.316166  47.567955  40.640053
# 65958 2000-01-05  47.389126  47.567955  43.141991  44.617310  38.119152
# 65959 2000-01-06  44.080830  44.349072  41.577251  42.918453  36.667717
# 65960 2000-01-07  42.247852  47.165592  42.203148  46.494991  39.723358
#
#         Volume Symbol              Security  GICS Sector  ...  Date added  \
# 65956  4674353      A  Agilent Technologies  Health Care  ...  2000-06-05
# 65957  4765083      A  Agilent Technologies  Health Care  ...  2000-06-05
# 65958  5758642      A  Agilent Technologies  Health Care  ...  2000-06-05
# 65959  2534434      A  Agilent Technologies  Health Care  ...  2000-06-05
# 65960  2819626      A  Agilent Technologies  Health Care  ...  2000-06-05
#
#            CIK Founded        Dia Dif Open-Close Dif_Sign     SMA_50  \
# ...

# %% [markdown]
# **CRUCE DE MEDIAS SIMPLES SMA** Cuando la SMA de 50 días cruza por encima de la SMA de 200 días, se considera una señal de compra (cruce dorado), mientras que cuando la SMA de 50 días cruza por debajo de la SMA de 200 días, se considera una señal de venta (cruce de la muerte).

# %%
import plotly.graph_objects as go

symbol = 'MMM'  # Reemplaza 
# Filtrar el DataFrame para obtener solo los datos del símbolo específico
symbol_data = merged_df[merged_df['Symbol'] == symbol]

# Crear un gráfico de líneas con Plotly
fig = go.Figure()

# Agregar el precio de cierre al gráfico
fig.add_trace(go.Scatter(x=symbol_data['Date'], y=symbol_data['Close'],
                         mode='lines', name='Close'))

# Agregar la SMA de 50 días al gráfico
fig.add_trace(go.Scatter(x=symbol_data['Date'], y=symbol_data['SMA_50'],
                         mode='lines', name='SMA 50'))

# Agregar la SMA de 200 días al gráfico
fig.add_trace(go.Scatter(x=symbol_data['Date'], y=symbol_data['SMA_200'],
                         mode='lines', name='SMA 200'))

# Personalizar el gráfico (título, ejes, etc.)
fig.update_layout(title=f'Cruce de medias móviles para {symbol}',
                  xaxis_title='Fecha',
                  yaxis_title='Precio')

# Mostrar el gráfico
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **CRUCE DE MEDIAS EXPONENCIAL EMA** Cuando la EMA de 12 días cruza por encima de la EMA de 26 días, se considera una señal de compra, mientras que cuando la EMA de 12 días cruza por debajo de la EMA de 26 días, se considera una señal de venta.

# %%
import plotly.graph_objects as go

symbol = 'MMM'  # Reemplazar

# Filtrar el DataFrame para obtener solo los datos del símbolo específico
symbol_data = merged_df[merged_df['Symbol'] == symbol]

# Crear un gráfico de líneas con Plotly
fig = go.Figure()

# Agregar el precio de cierre al gráfico
fig.add_trace(go.Scatter(x=symbol_data['Date'], y=symbol_data['Close'],
                         mode='lines', name='Close'))

# Agregar la EMA de 12 días al gráfico
fig.add_trace(go.Scatter(x=symbol_data['Date'], y=symbol_data['EMA_12'],
                         mode='lines', name='EMA 12'))

# Agregar la EMA de 26 días al gráfico
fig.add_trace(go.Scatter(x=symbol_data['Date'], y=symbol_data['EMA_26'],
                         mode='lines', name='EMA 26'))

# Personalizar el gráfico (título, ejes, etc.)
fig.update_layout(title=f'Cruce de medias móviles exponenciales para {symbol}',
                  xaxis_title='Fecha',
                  yaxis_title='Precio')

# Mostrar el gráfico
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **BAJO S&P GENERAL**

# %%
# Símbolo del índice S&P 500
sp500_index_symbol = '^GSPC'

# Definir el rango de fechas
start_date = '2000-01-01'
end_date = '2023-03-22'

# Descargar los datos del índice S&P 500
print(f"Descargando datos para {sp500_index_symbol}...")
sp500_index_data = yf.download(sp500_index_symbol, start=start_date, end=end_date)

print(sp500_index_data)
# Out:
# Descargando datos para ^GSPC...
# [*********************100%***********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2000-01-03  1469.250000  1478.000000  1438.359985  1455.219971  1455.219971
# 2000-01-04  1455.219971  1455.219971  1397.430054  1399.420044  1399.420044
# 2000-01-05  1399.420044  1413.270020  1377.680054  1402.109985  1402.109985
# 2000-01-06  1402.109985  1411.900024  1392.099976  1403.449951  1403.449951
# 2000-01-07  1403.449951  1441.469971  1400.729980  1441.469971  1441.469971
# ...                 ...          ...          ...          ...          ...
# 2023-03-15  3876.739990  3894.260010  3838.239990  3891.929932  3891.929932
# 2023-03-16  3878.929932  3964.459961  3864.110107  3960.280029  3960.280029
# 2023-03-17  3958.689941  3958.909912  3901.270020  3916.639893  3916.639893
# 2023-03-20  3917.469971  3956.620117  3916.889893  3951.570068  3951.570068
# ...

# %%
sp500_index_data = sp500_index_data.reset_index()

# %%
sp500_index_data.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
sp500_index_data.head()
# Out:
#         Date         Open         High          Low        Close    Adj Close  \
# 0 2000-01-03  1469.250000  1478.000000  1438.359985  1455.219971  1455.219971
# 1 2000-01-04  1455.219971  1455.219971  1397.430054  1399.420044  1399.420044
# 2 2000-01-05  1399.420044  1413.270020  1377.680054  1402.109985  1402.109985
# 3 2000-01-06  1402.109985  1411.900024  1392.099976  1403.449951  1403.449951
# 4 2000-01-07  1403.449951  1441.469971  1400.729980  1441.469971  1441.469971
#
#        Volume
# 0   931800000
# 1  1009000000
# 2  1085500000
# 3  1092300000
# 4  1225200000

# %%
unique_values_count = sp500_index_data['Date'].nunique()
print(unique_values_count)
# Out:
# 5841

# %%
sp500_index_data['symbol'] = '^GSPC'

# %%
sp500_index_data.head()
# Out:
#         Date         Open         High          Low        Close    Adj Close  \
# 0 2000-01-03  1469.250000  1478.000000  1438.359985  1455.219971  1455.219971
# 1 2000-01-04  1455.219971  1455.219971  1397.430054  1399.420044  1399.420044
# 2 2000-01-05  1399.420044  1413.270020  1377.680054  1402.109985  1402.109985
# 3 2000-01-06  1402.109985  1411.900024  1392.099976  1403.449951  1403.449951
# 4 2000-01-07  1403.449951  1441.469971  1400.729980  1441.469971  1441.469971
#
#        Volume symbol
# 0   931800000  ^GSPC
# 1  1009000000  ^GSPC
# 2  1085500000  ^GSPC
# 3  1092300000  ^GSPC
# 4  1225200000  ^GSPC

# %%
import pandas as pd
import plotly.graph_objects as go

# Asumiendo que tu DataFrame se llama 'sp500_index_data'
# Convertir la columna 'Date' a formato datetime
sp500_index_data['Date'] = pd.to_datetime(sp500_index_data['Date'])

# Crear un gráfico de velas con Plotly
fig = go.Figure(data=[go.Candlestick(x=sp500_index_data['Date'],
                open=sp500_index_data['Open'],
                high=sp500_index_data['High'],
                low=sp500_index_data['Low'],
                close=sp500_index_data['Close'])])

# Personalizar el gráfico (título, ejes, etc.)
fig.update_layout(title='Gráfico de velas del índice S&P 500 (^GSPC)',
                  xaxis_title='Fecha',
                  yaxis_title='Precio',
                  xaxis_rangeslider_visible=False)

# Establecer marcas en el eje x para cada año
fig.update_xaxes(
    tickvals=pd.date_range(start=sp500_index_data['Date'].min(), end=sp500_index_data['Date'].max(), freq='Y'),
    tickformat="%Y"
)

# Mostrar el gráfico
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pyarrow as pa
import pyarrow.parquet as pq

# %%
archivo = pa.Table.from_pandas(merged_df)
pq.write_table(archivo, 'EdaSyP.parquet')

# %%
sp500_index_data.to_csv('sp500.csv')
